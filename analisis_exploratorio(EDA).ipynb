# %%
#Install profiling
pip install ydata-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importar librerias
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %%
#Importar data sets 
cash_request0 = pd.read_csv('./project_dataset/extract - cash request - data analyst.csv')
fees0 = pd.read_csv('./project_dataset/extract - fees - data analyst - .csv')

# %%
# Copia del DataFrame original para evitar modificaciones no deseadas
cash_request = cash_request0.copy()
fees = fees0.copy()

# %%
# Creacion del profile
profile = ProfileReport(cash_request, title="Profiling Report")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.10.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-10-14 19:23:09.249225&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
